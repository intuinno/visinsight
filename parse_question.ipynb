# %%
import json

# %%
qa_pairs_path = '../sample_train1/qa_pairs.json'

# %%
with open(qa_pairs_path) as qa_fp:
    qa = json.load(qa_fp)

# %%
qa['qa_pairs'][2]
# Out:
# {u'answer': 1,
#  u'color1_id': 12,
#  u'color1_name': u'Cyan',
#  u'color1_rgb': [0, 255, 255],
#  u'color2_id': 28,
#  u'color2_name': u'Dark Turquoise',
#  u'color2_rgb': [0, 206, 209],
#  u'image_index': 0,
#  u'question_id': 3,
#  u'question_string': u'Is Cyan greater than Dark Turquoise?'}

# %%
def addComment(cDict, image_index, c):
    if image_index not in cDict:
        cDict[image_index] = []
    cDict[image_index].append(c)

# %%
qa_pairs = qa['qa_pairs']
cDict = {}

for q in qa_pairs:
    if q['question_id'] == 0:
        if q['answer'] == 1:
            c = '%s is the minimum.'%q['color1_name']
            addComment(cDict, q['image_index'], c)
    elif q['question_id'] == 1:
        if q['answer'] == 1:
            c = '%s is the maximum.'%q['color1_name']
            addComment(cDict, q['image_index'], c)
    elif q['question_id'] == 2:
#         print q['question_string']
        if q['answer'] == 1:
            c = '%s is less than the %s.'%(q['color1_name'], q['color2_name'])
            addComment(cDict, q['image_index'], c)
    elif q['question_id'] == 3:
#         print q['question_string']
        if q['answer'] == 1:
            c = '%s is greater than the %s.'%(q['color1_name'], q['color2_name'])
            addComment(cDict, q['image_index'], c)
    elif q['question_id'] == 4:
#         print q['question_string']
        if q['answer'] == 1:
            c = '%s is the low median.'%q['color1_name']
            addComment(cDict, q['image_index'], c)
    elif q['question_id'] == 5:
#         print q['question_string']
        if q['answer'] == 1:
            c = '%s is the high median.'%q['color1_name']
            addComment(cDict, q['image_index'], c)
    elif q['question_id'] == 6:
#         print q['question_string']
        if q['answer'] == 1:
            c = '%s has the minimum area under curve.'%q['color1_name']
            addComment(cDict, q['image_index'], c)
    elif q['question_id'] == 7:
#         print q['question_string']
        if q['answer'] == 1:
            c = '%s has the maximum area under curve.'%q['color1_name']
            addComment(cDict, q['image_index'], c)
    elif q['question_id'] == 8:
#         print q['question_string']
        if q['answer'] == 1:
            c = '%s is the smoothest.'%q['color1_name']
            addComment(cDict, q['image_index'], c)
    elif q['question_id'] == 9:
#         print q['question_string']
        if q['answer'] == 1:
            c = '%s is the roughest.'%q['color1_name']
            addComment(cDict, q['image_index'], c)
    elif q['question_id'] == 10:
#         print q['question_string']
        if q['answer'] == 1:
            c = '%s has the lowest value.'%q['color1_name']
            addComment(cDict, q['image_index'], c)
    elif q['question_id'] == 11:
#         print q['question_string']
        if q['answer'] == 1:
            c = '%s has the highest value.'%q['color1_name']
            addComment(cDict, q['image_index'], c)
    elif q['question_id'] == 12:
#         print q['question_string']
        if q['answer'] == 1:
            c = '%s is less than %s.'%(q['color1_name'], q['color2_name'])
            addComment(cDict, q['image_index'], c)
    elif q['question_id'] == 13:
#         print q['question_string']
        if q['answer'] == 1:
            c = '%s is greater than %s.'%(q['color1_name'], q['color2_name'])
            addComment(cDict, q['image_index'], c)
    elif q['question_id'] == 14:
#         print q['question_string']
        if q['answer'] == 1:
            c = '%s intersects %s.'%(q['color1_name'], q['color2_name'])
            addComment(cDict, q['image_index'], c)

# %%
cDict
# Out:
# {0: [u'Cyan is greater than the Dark Turquoise.',
#   u'Dark Turquoise is less than the Cyan.',
#   u'Olive is the high median.',
#   u'Forest Green is the low median.'],
#  1: [u'Blue is the minimum.',
#   u'Olive is the maximum.',
#   u'Olive is greater than the Blue.',
#   u'Blue is less than the Olive.',
#   u'Gray is the high median.',
#   u'Gray is the low median.'],
#  2: [u'Steel Blue is the minimum.',
#   u'Olive is the maximum.',
#   u'Olive is greater than the Dark Turquoise.',
#   u'Dark Turquoise is less than the Olive.',
#   u'Dark Turquoise is the high median.',
#   u'Dark Turquoise is the low median.'],
#  3: [u'Orange Red is greater than the Bubblegum.',
#   u'Bubblegum is less than the Orange Red.',
#   u'Cyan is the high median.',
#   u'Cyan is the low median.'],
#  4: [u'Periwinkle is the minimum.',
#   u'Dark Orchid is the maximum.',
#   u'Dark Gold is greater than the Light Seafoam.',
#   u'Light Seafoam is less than the Dark Gold.',
#   u'Dark Gold is the high median.',
#   u'Light Seafoam is the low median.'],
#  5: [u'Orchid is the minimum.',
#   u'Bubblegum is the maximum.',
#   u'Maroon is greater than the Purple.',
#   u'Purple is less than the Maroon.',
#   u'Medium Seafoam is the high median.',
#   u'Dark Blue is the low median.'],
#  6: [u'Dark Green is greater than the Medium Purple.',
#   u'Medium Purple is less than the Dark Green.',
#   u'Medium Purple is the high median.',
#   u'Khaki is the low median.'],
#  7: [u'Dark Gold is the minimum.',
#   u'Purple is the maximum.',
#   u'Purple is greater than the Dark Gold.',
#   u'Dark Gold is less than the Purple.',
#   u'Purple is the high median.',
#   u'Dark Gold is the low median.'],
#  8: [u'Cyan is the minimum.',
#   u'Medium Seafoam is the maximum.',
#   u'Seafoam is greater than the Firebrick.',
#   u'Firebrick is less than the Seafoam.',
#   u'Peru is the high median.',
#   u'Medium Blue is the low median.'],
#  9: [u'Gold is the minimum.',
#   u'Midnight Blue is the maximum.',
#   u'Maroon is greater than the Cyan.',
#   u'Cyan is less than the Maroon.',
#   u'Cornflower is the high median.',
#   u'Orange is the low median.'],
#  10: [u'Turquoise is the minimum.',
#   u'Aqua is the maximum.',
#   u'Dark Salmon is greater than the Saddle Brown.',
#   u'Saddle Brown is less than the Dark Salmon.',
#   u'Light Gold is the high median.',
#   u'Light Gold is the low median.'],
#  11: [u'Orange Red is the maximum.',
#   u'Peru is greater than the Medium Purple.',
#   u'Medium Purple is less than the Peru.',
#   u'Coral is the high median.',
#   u'Coral is the low median.'],
#  12: [u'Orange is the minimum.',
#   u'Dark Turquoise is the maximum.',
#   u'Dark Turquoise is greater than the Medium Seafoam.',
#   u'Medium Seafoam is less than the Dark Turquoise.',
#   u'Light Slate is the high median.',
#   u'Light Slate is the low median.'],
#  13: [u'Khaki is the minimum.',
#   u'Coral is the maximum.',
#   u'Coral is greater than the Khaki.',
#   u'Khaki is less than the Coral.',
#   u'Coral is the high median.',
#   u'Khaki is the low median.'],
#  14: [u'Pale Green is the minimum.',
#   u'Blue is the maximum.',
#   u'Blue is greater than the Medium Seafoam.',
#   u'Medium Seafoam is less than the Blue.',
#   u'Tomato is the high median.',
#   u'Medium Purple is the low median.'],
#  15: [u'Gray is the minimum.',
#   u'Cornflower is the maximum.',
#   u'Peru is greater than the Gray.',
#   u'Gray is less than the Peru.',
#   u'Peru is the high median.',
#   u'Peru is the low median.'],
#  16: [u'Olive is the minimum.',
#   u'Purple is the maximum.',
#   u'Purple is greater than the Olive.',
#   u'Olive is less than the Purple.',
#   u'Purple is the high median.',
#   u'Olive is the low median.'],
#  17: [u'Seafoam is the minimum.',
#   u'Steel Blue is the maximum.',
#   u'Steel Blue is greater than the Seafoam.',
#   u'Seafoam is less than the Steel Blue.',
#   u'Steel Blue is the high median.',
#   u'Seafoam is the low median.'],
#  18: [u'Crimson is the minimum.',
#   u'Medium Blue is the maximum.',
#   u'Medium Blue is greater than the Light Slate.',
#   u'Light Slate is less than the Medium Blue.',
#   u'Brown is the high median.',
#   u'Brown is the low median.'],
#  19: [u'Gold is the minimum.',
#   u'Turquoise is the maximum.',
#   u'Turquoise is greater than the Dark Orange.',
#   u'Dark Orange is less than the Turquoise.',
#   u'Dark Orange is the high median.',
#   u'Dark Orange is the low median.'],
#  20: [u'Red is the minimum.',
#   u'Medium Orchid is the maximum.',
#   u'Medium Orchid is greater than the Violet Red.',
#   u'Violet Red is less than the Medium Orchid.',
#   u'Green Yellow is the high median.',
#   u'Green Yellow is the low median.'],
#  21: [u'Tomato is the minimum.',
#   u'Dark Blue is the maximum.',
#   u'Firebrick is greater than the Tomato.',
#   u'Tomato is less than the Firebrick.',
#   u'Green Yellow is the high median.',
#   u'Firebrick is the low median.'],
#  22: [u'Olive is the minimum.',
#   u'Dark Blue is the maximum.',
#   u'Dark Blue is greater than the Medium Aqua.',
#   u'Medium Aqua is less than the Dark Blue.',
#   u'Medium Aqua is the high median.',
#   u'Medium Aqua is the low median.'],
#  24: [u'Dark Gold is the minimum.',
#   u'Orchid is the maximum.',
#   u'Orchid is greater than the Saddle Brown.',
#   u'Saddle Brown is less than the Orchid.',
#   u'Saddle Brown is the high median.',
#   u'Purple is the low median.'],
#  25: [u'Light Gold is the minimum.',
#   u'Dark Blue is the maximum.',
#   u'Pale Green is greater than the Gold.',
#   u'Gold is less than the Pale Green.',
#   u'Pale Green is the high median.',
#   u'Pale Green is the low median.'],
#  26: [u'Orange is the minimum.',
#   u'Khaki is the maximum.',
#   u'Khaki is greater than the Cornflower.',
#   u'Cornflower is less than the Khaki.',
#   u'Dark Green is the high median.',
#   u'Aqua is the low median.'],
#  27: [u'Orange Red is the minimum.',
#   u'Light Slate is the maximum.',
#   u'Midnight Blue is greater than the Medium Seafoam.',
#   u'Medium Seafoam is less than the Midnight Blue.',
#   u'Midnight Blue is the high median.',
#   u'Medium Seafoam is the low median.'],
#  28: [u'Royal Blue is the minimum.',
#   u'Dark Orange is the maximum.',
#   u'Bubblegum is greater than the Royal Blue.',
#   u'Royal Blue is less than the Bubblegum.',
#   u'Steel Blue is the high median.',
#   u'Steel Blue is the low median.'],
#  29: [u'Green Yellow is the minimum.',
#   u'Seafoam is the maximum.',
#   u'Seafoam is greater than the Cyan.',
#   u'Cyan is less than the Seafoam.',
#   u'Cyan is the high median.',
#   u'Steel Blue is the low median.'],
#  30: [u'Periwinkle is the minimum.',
#   u'Dark Salmon is the maximum.',
#   u'Crimson is greater than the Periwinkle.',
#   u'Periwinkle is less than the Crimson.',
#   u'Peru is the high median.',
#   u'Peru is the low median.'],
#  31: [u'Dark Gold is the minimum.',
#   u'Firebrick is the maximum.',
#   u'Cornflower is greater than the Khaki.',
#   u'Khaki is less than the Cornflower.',
#   u'Red is the high median.',
#   u'Crimson is the low median.'],
#  32: [u'Dark Red is the minimum.',
#   u'Medium Purple is the maximum.',
#   u'Dark Orchid is greater than the Bubblegum.',
#   u'Bubblegum is less than the Dark Orchid.',
#   u'Bubblegum is the high median.',
#   u'Bubblegum is the low median.'],
#  33: [u'Blue Violet is the minimum.',
#   u'Blue is the maximum.',
#   u'Orange Red is greater than the Blue Violet.',
#   u'Blue Violet is less than the Orange Red.',
#   u'Orange Red is the high median.',
#   u'Orange Red is the low median.'],
#  34: [u'Dark Salmon is the minimum.',
#   u'Orange Red is the maximum.',
#   u'Brown is greater than the Dark Salmon.',
#   u'Dark Salmon is less than the Brown.',
#   u'Brown is the high median.',
#   u'Brown is the low median.'],
#  35: [u'Light Slate is the minimum.',
#   u'Brown is the maximum.',
#   u'Brown is greater than the Gray.',
#   u'Gray is less than the Brown.',
#   u'Purple is the high median.',
#   u'Purple is the low median.'],
#  36: [u'Green Yellow is the minimum.',
#   u'Crimson is the maximum.',
#   u'Dark Salmon is greater than the Green Yellow.',
#   u'Green Yellow is less than the Dark Salmon.',
#   u'Dark Orange is the high median.',
#   u'Dark Orange is the low median.'],
#  37: [u'Periwinkle is the minimum.',
#   u'Gold is the maximum.',
#   u'Midnight Blue is greater than the Dark Orange.',
#   u'Dark Orange is less than the Midnight Blue.',
#   u'Midnight Blue is the high median.',
#   u'Midnight Blue is the low median.'],
#  38: [u'Pale Green is the minimum.',
#   u'Dark Red is the maximum.',
#   u'Dark Red is greater than the Pale Green.',
#   u'Pale Green is less than the Dark Red.',
#   u'Dark Red is the high median.',
#   u'Pale Green is the low median.'],
#  39: [u'Dark Green is the minimum.',
#   u'Cyan is the maximum.',
#   u'Cyan is greater than the Aqua.',
#   u'Aqua is less than the Cyan.',
#   u'Red is the high median.',
#   u'Aqua is the low median.'],
#  40: [u'Steel Blue is the minimum.',
#   u'Orange Red is the maximum.',
#   u'Orange Red is greater than the Steel Blue.',
#   u'Steel Blue is less than the Orange Red.',
#   u'Orange Red is the high median.',
#   u'Steel Blue is the low median.'],
#  41: [u'Firebrick is greater than the Green Yellow.',
#   u'Green Yellow is less than the Firebrick.',
#   u'Royal Blue is the high median.',
#   u'Steel Blue is the low median.'],
#  42: [u'Medium Purple is the minimum.',
#   u'Medium Orchid is the maximum.',
#   u'Pale Green is greater than the Medium Purple.',
#   u'Medium Purple is less than the Pale Green.',
#   u'Light Seafoam is the high median.',
#   u'Light Slate is the low median.'],
#  43: [u'Orange Red is greater than the Gold.',
#   u'Gold is less than the Orange Red.',
#   u'Orange Red is the high median.',
#   u'Gold is the low median.'],
#  44: [u'Aqua is the minimum.',
#   u'Forest Green is the maximum.',
#   u'Light Slate is greater than the Red.',
#   u'Red is less than the Light Slate.',
#   u'Light Green is the high median.',
#   u'Light Green is the low median.'],
#  45: [u'Khaki is the maximum.',
#   u'Gray is greater than the Blue Violet.',
#   u'Blue Violet is less than the Gray.',
#   u'Violet Red is the high median.',
#   u'Violet Red is the low median.'],
#  46: [u'Medium Blue is greater than the Medium Orchid.',
#   u'Medium Orchid is less than the Medium Blue.',
#   u'Medium Blue is the high median.',
#   u'Medium Blue is the low median.'],
#  47: [u'Medium Blue is the minimum.',
#   u'Coral is the maximum.',
#   u'Coral is greater than the Medium Blue.',
#   u'Medium Blue is less than the Coral.',
#   u'Coral is the high median.',
#   u'Medium Blue is the low median.'],
#  48: [u'Orchid is the minimum.',
#   u'Purple is the maximum.',
#   u'Purple is greater than the Orchid.',
#   u'Orchid is less than the Purple.',
#   u'Purple is the high median.',
#   u'Orchid is the low median.'],
#  49: [u'Forest Green is the minimum.',
#   u'Brown is the maximum.',
#   u'Brown is greater than the Blue.',
#   u'Blue is less than the Brown.',
#   u'Orange Red is the high median.',
#   u'Blue is the low median.'],
#  50: [u'Purple is the minimum.',
#   u'Seafoam is the maximum.',
#   u'Seafoam is greater than the Royal Blue.',
#   u'Royal Blue is less than the Seafoam.',
#   u'Turquoise is the high median.',
#   u'Turquoise is the low median.'],
#  51: [u'Dark Green is the minimum.',
#   u'Dark Orange is the maximum.',
#   u'Cyan is greater than the Dark Green.',
#   u'Dark Green is less than the Cyan.',
#   u'Red is the high median.',
#   u'Olive is the low median.'],
#  52: [u'Dark Turquoise is the minimum.',
#   u'Dark Red is the maximum.',
#   u'Firebrick is greater than the Light Slate.',
#   u'Light Slate is less than the Firebrick.',
#   u'Light Slate is the high median.',
#   u'Seafoam is the low median.'],
#  53: [u'Tomato is the minimum.',
#   u'Coral is the maximum.',
#   u'Steel Blue is greater than the Tomato.',
#   u'Tomato is less than the Steel Blue.',
#   u'Olive is the high median.',
#   u'Olive is the low median.'],
#  54: [u'Blue is the minimum.',
#   u'Coral is the maximum.',
#   u'Coral is greater than the Pale Green.',
#   u'Pale Green is less than the Coral.',
#   u'Light Green is the high median.',
#   u'Cyan is the low median.'],
#  55: [u'Peru is the minimum.',
#   u'Dark Green is the maximum.',
#   u'Khaki is greater than the Dark Salmon.',
#   u'Dark Salmon is less than the Khaki.',
#   u'Gold is the high median.',
#   u'Khaki is the low median.'],
#  56: [u'Medium Purple is the minimum.',
#   u'Medium Seafoam is the maximum.',
#   u'Medium Seafoam is greater than the Medium Purple.',
#   u'Medium Purple is less than the Medium Seafoam.',
#   u'Medium Seafoam is the high median.',
#   u'Medium Purple is the low median.'],
#  57: [u'Orange is the minimum.',
#   u'Blue Violet is the maximum.',
#   u'Blue Violet is greater than the Crimson.',
#   u'Crimson is less than the Blue Violet.',
#   u'Orchid is the high median.',
#   u'Orchid is the low median.'],
#  58: [u'Orange Red is the minimum.',
#   u'Dark Green is the maximum.',
#   u'Dark Green is greater than the Khaki.',
#   u'Khaki is less than the Dark Green.',
#   u'Coral is the high median.',
#   u'Aqua is the low median.'],
#  59: [u'Light Seafoam is the minimum.',
#   u'Dark Gold is the maximum.',
#   u'Dark Gold is greater than the Maroon.',
#   u'Maroon is less than the Dark Gold.',
#   u'Maroon is the high median.',
#   u'Maroon is the low median.'],
#  60: [u'Light Green is the minimum.',
#   u'Brown is the maximum.',
#   u'Medium Aqua is greater than the Light Green.',
#   u'Light Green is less than the Medium Aqua.',
#   u'Purple is the high median.',
#   u'Olive is the low median.'],
#  61: [u'Forest Green is the minimum.',
#   u'Light Green is the maximum.',
#   u'Light Green is greater than the Seafoam.',
#   u'Seafoam is less than the Light Green.',
#   u'Seafoam is the high median.',
#   u'Gray is the low median.'],
#  62: [u'Violet Red is greater than the Pale Green.',
#   u'Pale Green is less than the Violet Red.',
#   u'Seafoam is the high median.',
#   u'Violet Red is the low median.'],
#  63: [u'Dark Orchid is the minimum.',
#   u'Medium Blue is the maximum.',
#   u'Medium Blue is greater than the Dark Orchid.',
#   u'Dark Orchid is less than the Medium Blue.',
#   u'Blue Violet is the high median.',
#   u'Blue Violet is the low median.'],
#  64: [u'Periwinkle is the minimum.',
#   u'Light Gold is the maximum.',
#   u'Light Gold is greater than the Periwinkle.',
#   u'Periwinkle is less than the Light Gold.',
#   u'Light Gold is the high median.',
#   u'Periwinkle is the low median.'],
#  65: [u'Orange is the minimum.',
#   u'Dark Turquoise is the maximum.',
#   u'Midnight Blue is greater than the Orange.',
#   u'Orange is less than the Midnight Blue.',
#   u'Dark Green is the high median.',
#   u'Dark Green is the low median.'],
#  66: [u'Aqua is the minimum.',
#   u'Violet Red is the maximum.',
#   u'Violet Red is greater than the Red.',
#   u'Red is less than the Violet Red.',
#   u'Khaki is the high median.',
#   u'Orange is the low median.'],
#  67: [u'Purple is the minimum.',
#   u'Bubblegum is the maximum.',
#   u'Bubblegum is greater than the Orange Red.',
#   u'Orange Red is less than the Bubblegum.',
#   u'Orange Red is the high median.',
#   u'Orange Red is the low median.'],
#  68: [u'Medium Purple is greater than the Aqua.',
#   u'Aqua is less than the Medium Purple.',
#   u'Turquoise is the high median.',
#   u'Turquoise is the low median.'],
#  69: [u'Dark Orchid is the minimum.',
#   u'Gray is the maximum.',
#   u'Gray is greater than the Cornflower.',
#   u'Cornflower is less than the Gray.',
#   u'Medium Orchid is the high median.',
#   u'Medium Orchid is the low median.'],
#  70: [u'Light Seafoam is the minimum.',
#   u'Dark Green is the maximum.',
#   u'Midnight Blue is greater than the Cyan.',
#   u'Cyan is less than the Midnight Blue.',
#   u'Steel Blue is the high median.',
#   u'Light Slate is the low median.'],
#  71: [u'Medium Aqua is the minimum.',
#   u'Peru is the maximum.',
#   u'Peru is greater than the Dark Blue.',
#   u'Dark Blue is less than the Peru.',
#   u'Tomato is the high median.',
#   u'Blue Violet is the low median.'],
#  72: [u'Orchid is the minimum.',
#   u'Forest Green is the maximum.',
#   u'Forest Green is greater than the Royal Blue.',
#   u'Royal Blue is less than the Forest Green.',
#   u'Light Seafoam is the high median.',
#   u'Light Seafoam is the low median.'],
#  73: [u'Violet Red is the minimum.',
#   u'Dark Gold is the maximum.',
#   u'Dark Gold is greater than the Orchid.',
#   u'Orchid is less than the Dark Gold.',
#   u'Brown is the high median.',
#   u'Dark Red is the low median.'],
#  74: [u'Medium Purple is the minimum.',
#   u'Periwinkle is the maximum.',
#   u'Periwinkle is greater than the Peru.',
#   u'Peru is less than the Periwinkle.',
#   u'Light Seafoam is the high median.',
#   u'Light Seafoam is the low median.'],
#  75: [u'Seafoam is the minimum.',
#   u'Gray is the maximum.',
#   u'Gray is greater than the Seafoam.',
#   u'Seafoam is less than the Gray.',
#   u'Gold is the high median.',
#   u'Gold is the low median.'],
#  76: [u'Orange is the minimum.',
#   u'Dark Red is the maximum.',
#   u'Dark Red is greater than the Blue Violet.',
#   u'Blue Violet is less than the Dark Red.',
#   u'Forest Green is the high median.',
#   u'Light Green is the low median.'],
#  77: [u'Khaki is the minimum.',
#   u'Brown is the maximum.',
#   u'Olive is greater than the Khaki.',
#   u'Khaki is less than the Olive.',
#   u'Red is the high median.',
#   u'Red is the low median.'],
#  78: [u'Dark Orange is the minimum.',
#   u'Aqua is the maximum.',
#   u'Aqua is greater than the Dark Orange.',
#   u'Dark Orange is less than the Aqua.',
#   u'Aqua is the high median.',
#   u'Dark Orange is the low median.'],
#  79: [u'Dark Turquoise is the minimum.',
#   u'Medium Blue is the maximum.',
#   u'Dark Blue is greater than the Dark Turquoise.',
#   u'Dark Turquoise is less than the Dark Blue.',
#   u'Dark Blue is the high median.',
#   u'Dark Blue is the low median.'],
#  80: [u'Dark Orange is the minimum.',
#   u'Dark Blue is the maximum.',
#   u'Dark Blue is greater than the Peru.',
#   u'Peru is less than the Dark Blue.',
#   u'Peru is the high median.',
#   u'Orchid is the low median.'],
#  81: [u'Dark Orange is the minimum.',
#   u'Dark Gold is the maximum.',
#   u'Gold is greater than the Dark Orange.',
#   u'Dark Orange is less than the Gold.',
#   u'Seafoam is the high median.',
#   u'Light Gold is the low median.'],
#  82: [u'Violet Red is greater than the Medium Orchid.',
#   u'Medium Orchid is less than the Violet Red.',
#   u'Dark Orange is the high median.',
#   u'Seafoam is the low median.'],
#  83: [u'Dark Orchid is the minimum.',
#   u'Dark Gold is the maximum.',
#   u'Dark Gold is greater than the Dark Orchid.',
#   u'Dark Orchid is less than the Dark Gold.',
#   u'Olive is the high median.',
#   u'Olive is the low median.'],
#  84: [u'Orange is the minimum.',
#   u'Light Gold is the maximum.',
#   u'Royal Blue is greater than the Orange.',
#   u'Orange is less than the Royal Blue.',
#   u'Khaki is the high median.',
#   u'Khaki is the low median.'],
#  85: [u'Turquoise is the minimum.',
#   u'Maroon is the maximum.',
#   u'Bubblegum is greater than the Turquoise.',
#   u'Turquoise is less than the Bubblegum.',
#   u'Dark Gold is the high median.',
#   u'Dark Gold is the low median.'],
#  86: [u'Aqua is the minimum.',
#   u'Purple is the maximum.',
#   u'Periwinkle is greater than the Blue.',
#   u'Blue is less than the Periwinkle.',
#   u'Crimson is the high median.',
#   u'Medium Purple is the low median.'],
#  87: [u'Aqua is greater than the Forest Green.',
#   u'Forest Green is less than the Aqua.',
#   u'Aqua is the high median.',
#   u'Aqua is the low median.'],
#  88: [u'Turquoise is the minimum.',
#   u'Green Yellow is the maximum.',
#   u'Dark Orange is greater than the Medium Blue.',
#   u'Medium Blue is less than the Dark Orange.',
#   u'Midnight Blue is the high median.',
#   u'Midnight Blue is the low median.'],
#  89: [u'Dark Gold is the minimum.',
#   u'Green Yellow is the maximum.',
#   u'Green Yellow is greater than the Dark Gold.',
#   u'Dark Gold is less than the Green Yellow.',
#   u'Green Yellow is the high median.',
#   u'Dark Gold is the low median.'],
#  90: [u'Dark Orchid is greater than the Pale Green.',
#   u'Pale Green is less than the Dark Orchid.',
#   u'Steel Blue is the high median.',
#   u'Steel Blue is the low median.'],
#  91: [u'Peru is greater than the Green Yellow.',
#   u'Green Yellow is less than the Peru.',
#   u'Peru is the high median.',
#   u'Orchid is the low median.'],
#  92: [u'Dark Blue is the minimum.',
#   u'Orange Red is the maximum.',
#   u'Orange Red is greater than the Dark Blue.',
#   u'Dark Blue is less than the Orange Red.',
#   u'Orange Red is the high median.',
#   u'Dark Blue is the low median.'],
#  93: [u'Red is the minimum.',
#   u'Bubblegum is the maximum.',
#   u'Bubblegum is greater than the Cornflower.',
#   u'Cornflower is less than the Bubblegum.',
#   u'Gray is the high median.',
#   u'Gold is the low median.'],
#  94: [u'Blue is the minimum.',
#   u'Blue Violet is the maximum.',
#   u'Maroon is greater than the Gray.',
#   u'Gray is less than the Maroon.',
#   u'Coral is the high median.',
#   u'Coral is the low median.'],
#  95: [u'Crimson is the minimum.',
#   u'Tomato is the maximum.',
#   u'Olive is greater than the Khaki.',
#   u'Khaki is less than the Olive.',
#   u'Peru is the high median.',
#   u'Peru is the low median.'],
#  96: [u'Pale Green is the minimum.',
#   u'Violet Red is the maximum.',
#   u'Gray is greater than the Pale Green.',
#   u'Pale Green is less than the Gray.',
#   u'Dark Red is the high median.',
#   u'Dark Red is the low median.'],
#  97: [u'Royal Blue is greater than the Light Seafoam.',
#   u'Light Seafoam is less than the Royal Blue.',
#   u'Dark Salmon is the high median.',
#   u'Dark Salmon is the low median.'],
#  98: [u'Dark Red is the minimum.',
#   u'Green Yellow is the maximum.',
#   u'Green Yellow is greater than the Dark Red.',
#   u'Dark Red is less than the Green Yellow.',
#   u'Medium Blue is the high median.',
#   u'Medium Orchid is the low median.'],
#  99: [u'Olive is greater than the Peru.',
#   u'Peru is less than the Olive.',
#   u'Medium Aqua is the high median.',
#   u'Peru is the low median.'],
#  100: [u'Blue is the minimum.',
#   u'Turquoise is the maximum.',
#   u'Turquoise is greater than the Blue.',
#   u'Blue is less than the Turquoise.',
#   u'Turquoise is the high median.',
#   u'Blue is the low median.'],
#  101: [u'Dark Blue is the minimum.',
#   u'Dark Green is the maximum.',
#   u'Dark Green is greater than the Light Seafoam.',
#   u'Light Seafoam is less than the Dark Green.',
#   u'Violet Red is the high median.',
#   u'Light Seafoam is the low median.'],
#  102: [u'Saddle Brown is the minimum.',
#   u'Olive is the maximum.',
#   u'Green Yellow is greater than the Saddle Brown.',
#   u'Saddle Brown is less than the Green Yellow.',
#   u'Light Gold is the high median.',
#   u'Dark Blue is the low median.'],
#  103: [u'Violet Red is the minimum.',
#   u'Dark Orange is the maximum.',
#   u'Dark Orange is greater than the Violet Red.',
#   u'Violet Red is less than the Dark Orange.',
#   u'Dark Orange is the high median.',
#   u'Violet Red is the low median.'],
#  104: [u'Medium Purple is the minimum.',
#   u'Khaki is the maximum.',
#   u'Coral is greater than the Medium Purple.',
#   u'Medium Purple is less than the Coral.',
#   u'Crimson is the high median.',
#   u'Periwinkle is the low median.'],
#  105: [u'Dark Salmon is the minimum.',
#   u'Blue Violet is the maximum.',
#   u'Blue Violet is greater than the Olive.',
#   u'Olive is less than the Blue Violet.',
#   u'Aqua is the high median.',
#   u'Aqua is the low median.'],
#  106: [u'Seafoam is the minimum.',
#   u'Gray is the maximum.',
#   u'Gray is greater than the Crimson.',
#   u'Crimson is less than the Gray.',
#   u'Aqua is the high median.',
#   u'Dark Orchid is the low median.'],
#  107: [u'Coral is greater than the Forest Green.',
#   u'Forest Green is less than the Coral.',
#   u'Orchid is the high median.',
#   u'Dark Turquoise is the low median.'],
#  108: [u'Blue Violet is the minimum.',
#   u'Orange Red is the maximum.',
#   u'Orange Red is greater than the Firebrick.',
#   u'Firebrick is less than the Orange Red.',
#   u'Crimson is the high median.',
#   u'Dark Gold is the low median.'],
#  109: [u'Medium Purple is the minimum.',
#   u'Midnight Blue is the maximum.',
#   u'Cornflower is greater than the Medium Purple.',
#   u'Medium Purple is less than the Cornflower.',
#   u'Coral is the high median.',
#   u'Coral is the low median.'],
#  110: [u'Orange Red is the minimum.',
#   u'Khaki is the maximum.',
#   u'Khaki is greater than the Periwinkle.',
#   u'Periwinkle is less than the Khaki.',
#   u'Medium Orchid is the high median.',
#   u'Medium Orchid is the low median.'],
#  111: [u'Peru is the minimum.',
#   u'Aqua is the maximum.',
#   u'Aqua is greater than the Medium Blue.',
#   u'Medium Blue is less than the Aqua.',
#   u'Green Yellow is the high median.',
#   u'Green Yellow is the low median.'],
#  112: [u'Dark Blue is the minimum.',
#   u'Light Green is the maximum.',
#   u'Peru is greater than the Dark Blue.',
#   u'Dark Blue is less than the Peru.',
#   u'Peru is the high median.',
#   u'Peru is the low median.'],
#  113: [u'Seafoam is the minimum.',
#   u'Light Seafoam is the maximum.',
#   u'Royal Blue is greater than the Coral.',
#   u'Coral is less than the Royal Blue.',
#   u'Medium Orchid is the high median.',
#   u'Royal Blue is the low median.'],
#  114: [u'Pale Green is the minimum.',
#   u'Cyan is the maximum.',
#   u'Midnight Blue is greater than the Pale Green.',
#   u'Pale Green is less than the Midnight Blue.',
#   u'Royal Blue is the high median.',
#   u'Royal Blue is the low median.'],
#  115: [u'Orange Red is the minimum.',
#   u'Royal Blue is the maximum.',
#   u'Royal Blue is greater than the Dark Blue.',
#   u'Dark Blue is less than the Royal Blue.',
#   u'Dark Blue is the high median.',
#   u'Forest Green is the low median.'],
#  116: [u'Light Seafoam is the minimum.',
#   u'Medium Purple is the maximum.',
#   u'Medium Purple is greater than the Dark Blue.',
#   u'Dark Blue is less than the Medium Purple.',
#   u'Cyan is the high median.',
#   u'Crimson is the low median.'],
#  117: [u'Medium Blue is the minimum.',
#   u'Dark Orange is the maximum.',
#   u'Cyan is greater than the Medium Blue.',
#   u'Medium Blue is less than the Cyan.',
#   u'Cornflower is the high median.',
#   u'Cornflower is the low median.'],
#  118: [u'Steel Blue is the minimum.',
#   u'Medium Orchid is the maximum.',
#   u'Orange Red is greater than the Steel Blue.',
#   u'Steel Blue is less than the Orange Red.',
#   u'Orange Red is the high median.',
#   u'Orange Red is the low median.'],
#  119: [u'Periwinkle is the minimum.',
#   u'Green Yellow is the maximum.',
#   u'Blue Violet is greater than the Dark Green.',
#   u'Dark Green is less than the Blue Violet.',
#   u'Steel Blue is the high median.',
#   u'Blue Violet is the low median.'],
#  120: [u'Steel Blue is greater than the Dark Orchid.',
#   u'Dark Orchid is less than the Steel Blue.',
#   u'Purple is the high median.',
#   u'Light Gold is the low median.'],
#  121: [u'Light Green is the minimum.',
#   u'Green Yellow is the maximum.',
#   u'Green Yellow is greater than the Light Green.',
#   u'Light Green is less than the Green Yellow.',
#   u'Dark Salmon is the high median.',
#   u'Dark Salmon is the low median.'],
#  122: [u'Dark Green is the minimum.',
#   u'Blue Violet is the maximum.',
#   u'Aqua is greater than the Dark Green.',
#   u'Dark Green is less than the Aqua.',
#   u'Periwinkle is the high median.',
#   u'Periwinkle is the low median.'],
#  123: [u'Medium Blue is the minimum.',
#   u'Red is the maximum.',
#   u'Bubblegum is greater than the Medium Purple.',
#   u'Medium Purple is less than the Bubblegum.',
#   u'Medium Purple is the high median.',
#   u'Coral is the low median.'],
#  124: [u'Seafoam is greater than the Blue.',
#   u'Blue is less than the Seafoam.',
#   u'Peru is the high median.',
#   u'Steel Blue is the low median.'],
#  125: [u'Orange Red is the minimum.',
#   u'Coral is the maximum.',
#   u'Midnight Blue is greater than the Violet Red.',
#   u'Violet Red is less than the Midnight Blue.',
#   u'Gold is the high median.',
#   u'Olive is the low median.'],
#  126: [u'Gold is the minimum.',
#   u'Tomato is the maximum.',
#   u'Dark Blue is greater than the Gold.',
#   u'Gold is less than the Dark Blue.',
#   u'Medium Seafoam is the high median.',
#   u'Midnight Blue is the low median.'],
#  127: [u'Peru is greater than the Medium Seafoam.',
#   u'Medium Seafoam is less than the Peru.',
#   u'Dark Salmon is the high median.',
#   u'Peru is the low median.'],
#  128: [u'Medium Seafoam is the minimum.',
#   u'Orchid is the maximum.',
#   u'Dark Gold is greater than the Medium Seafoam.',
#   u'Medium Seafoam is less than the Dark Gold.',
#   u'Dark Gold is the high median.',
#   u'Dark Gold is the low median.'],
#  129: [u'Brown is the minimum.',
#   u'Light Green is the maximum.',
#   u'Turquoise is greater than the Red.',
#   u'Red is less than the Turquoise.',
#   u'Royal Blue is the high median.',
#   u'Royal Blue is the low median.'],
#  130: [u'Dark Green is greater than the Orange.',
#   u'Orange is less than the Dark Green.',
#   u'Orange is the high median.',
#   u'Bubblegum is the low median.'],
#  131: [u'Dark Orchid is the minimum.',
#   u'Royal Blue is the maximum.',
#   u'Seafoam is greater than the Dark Orchid.',
#   u'Dark Orchid is less than the Seafoam.',
#   u'Peru is the high median.',
#   u'Peru is the low median.'],
#  132: [u'Medium Aqua is the minimum.',
#   u'Dark Blue is the maximum.',
#   u'Dark Blue is greater than the Khaki.',
#   u'Khaki is less than the Dark Blue.',
#   u'Khaki is the high median.',
#   u'Dark Turquoise is the low median.'],
#  133: [u'Medium Purple is the minimum.',
#   u'Dark Orchid is the maximum.',
#   u'Medium Seafoam is greater than the Medium Purple.',
#   u'Medium Purple is less than the Medium Seafoam.',
#   u'Dark Orange is the high median.',
#   u'Red is the low median.'],
#  134: [u'Dark Gold is the minimum.',
#   u'Aqua is the maximum.',
#   u'Red is greater than the Firebrick.',
#   u'Firebrick is less than the Red.',
#   u'Red is the high median.',
#   u'Firebrick is the low median.'],
#  135: [u'Orange Red is the minimum.',
#   u'Maroon is the maximum.',
#   u'Gold is greater than the Khaki.',
#   u'Khaki is less than the Gold.',
#   u'Gold is the high median.',
#   u'Khaki is the low median.'],
#  136: [u'Aqua is the minimum.',
#   u'Saddle Brown is the maximum.',
#   u'Saddle Brown is greater than the Aqua.',
#   u'Aqua is less than the Saddle Brown.',
#   u'Saddle Brown is the high median.',
#   u'Aqua is the low median.'],
#  137: [u'Violet Red is the minimum.',
#   u'Dark Gold is the maximum.',
#   u'Gold is greater than the Violet Red.',
#   u'Violet Red is less than the Gold.',
#   u'Blue Violet is the high median.',
#   u'Gold is the low median.'],
#  138: [u'Dark Orange is greater than the Blue.',
#   u'Blue is less than the Dark Orange.',
#   u'Seafoam is the high median.',
#   u'Seafoam is the low median.'],
#  139: [u'Medium Blue is the minimum.',
#   u'Dark Red is the maximum.',
#   u'Dark Red is greater than the Periwinkle.',
#   u'Periwinkle is less than the Dark Red.',
#   u'Dark Orange is the high median.',
#   u'Dark Gold is the low median.'],
#  140: [u'Medium Purple is the minimum.',
#   u'Medium Orchid is the maximum.',
#   u'Medium Orchid is greater than the Medium Purple.',
#   u'Medium Purple is less than the Medium Orchid.',
#   u'Medium Orchid is the high median.',
#   u'Medium Purple is the low median.'],
#  141: [u'Dark Turquoise is the minimum.',
#   u'Light Seafoam is the maximum.',
#   u'Dark Blue is greater than the Dark Turquoise.',
#   u'Dark Turquoise is less than the Dark Blue.',
#   u'Medium Blue is the high median.',
#   u'Dark Blue is the low median.'],
#  142: [u'Cornflower is the minimum.',
#   u'Khaki is the maximum.',
#   u'Khaki is greater than the Medium Aqua.',
#   u'Medium Aqua is less than the Khaki.',
#   u'Medium Aqua is the high median.',
#   u'Dark Green is the low median.'],
#  143: [u'Orange is the minimum.',
#   u'Brown is the maximum.',
#   u'Brown is greater than the Orange.',
#   u'Orange is less than the Brown.',
#   u'Brown is the high median.',
#   u'Orange is the low median.'],
#  144: [u'Aqua is the maximum.',
#   u'Aqua is greater than the Light Slate.',
#   u'Light Slate is less than the Aqua.',
#   u'Seafoam is the high median.',
#   u'Medium Purple is the low median.'],
#  145: [u'Olive is the minimum.',
#   u'Purple is the maximum.',
#   u'Light Gold is greater than the Firebrick.',
#   u'Firebrick is less than the Light Gold.',
#   u'Dark Gold is the high median.',
#   u'Crimson is the low median.'],
#  146: [u'Coral is the minimum.',
#   u'Medium Aqua is the maximum.',
#   u'Dark Salmon is greater than the Green Yellow.',
#   u'Green Yellow is less than the Dark Salmon.',
#   u'Medium Purple is the high median.',
#   u'Dark Salmon is the low median.'],
#  147: [u'Coral is greater than the Gray.',
#   u'Gray is less than the Coral.',
#   u'Dark Turquoise is the high median.',
#   u'Medium Orchid is the low median.'],
#  148: [u'Aqua is greater than the Dark Salmon.',
#   u'Dark Salmon is less than the Aqua.',
#   u'Aqua is the high median.',
#   u'Dark Salmon is the low median.'],
#  149: [u'Crimson is greater than the Khaki.',
#   u'Khaki is less than the Crimson.',
#   u'Crimson is the high median.',
#   u'Khaki is the low median.'],
#  150: [u'Turquoise is the minimum.',
#   u'Gold is the maximum.',
#   u'Gold is greater than the Turquoise.',
#   u'Turquoise is less than the Gold.',
#   u'Medium Blue is the high median.',
#   u'Medium Orchid is the low median.'],
#  151: [u'Maroon is the minimum.',
#   u'Tomato is the maximum.',
#   u'Tomato is greater than the Maroon.',
#   u'Maroon is less than the Tomato.',
#   u'Dark Gold is the high median.',
#   u'Dark Gold is the low median.'],
#  152: [u'Blue Violet is the minimum.',
#   u'Steel Blue is the maximum.',
#   u'Dark Gold is greater than the Blue.',
#   u'Blue is less than the Dark Gold.',
#   u'Saddle Brown is the high median.',
#   u'Saddle Brown is the low median.'],
#  153: [u'Orchid is the minimum.',
#   u'Khaki is the maximum.',
#   u'Violet Red is greater than the Orchid.',
#   u'Orchid is less than the Violet Red.',
#   u'Violet Red is the high median.',
#   u'Violet Red is the low median.'],
#  154: [u'Brown is the minimum.',
#   u'Seafoam is the maximum.',
#   u'Light Slate is greater than the Brown.',
#   u'Brown is less than the Light Slate.',
#   u'Light Seafoam is the high median.',
#   u'Light Seafoam is the low median.'],
#  155: [u'Dark Gold is greater than the Midnight Blue.',
#   u'Midnight Blue is less than the Dark Gold.',
#   u'Bubblegum is the high median.',
#   u'Bubblegum is the low median.'],
#  156: [u'Peru is the minimum.',
#   u'Turquoise is the maximum.',
#   u'Medium Seafoam is greater than the Peru.',
#   u'Peru is less than the Medium Seafoam.',
#   u'Medium Seafoam is the high median.',
#   u'Dark Gold is the low median.'],
#  157: [u'Purple is the minimum.',
#   u'Periwinkle is the maximum.',
#   u'Pale Green is greater than the Purple.',
#   u'Purple is less than the Pale Green.',
#   u'Pale Green is the high median.',
#   u'Light Seafoam is the low median.'],
#  158: [u'Firebrick is the minimum.',
#   u'Green Yellow is the maximum.',
#   u'Medium Purple is greater than the Dark Green.',
#   u'Dark Green is less than the Medium Purple.',
#   u'Medium Purple is the high median.',
#   u'Medium Purple is the low median.'],
#  159: [u'Violet Red is the minimum.',
#   u'Orange is the maximum.',
#   u'Gray is greater than the Light Green.',
#   u'Light Green is less than the Gray.',
#   u'Peru is the high median.',
#   u'Light Green is the low median.'],
#  160: [u'Light Green is the minimum.',
#   u'Dark Gold is the maximum.',
#   u'Dark Gold is greater than the Light Green.',
#   u'Light Green is less than the Dark Gold.',
#   u'Dark Gold is the high median.',
#   u'Light Green is the low median.'],
#  161: [u'Green Yellow is the minimum.',
#   u'Medium Seafoam is the maximum.',
#   u'Saddle Brown is greater than the Tomato.',
#   u'Tomato is less than the Saddle Brown.',
#   u'Light Gold is the high median.',
#   u'Light Gold is the low median.'],
#  162: [u'Steel Blue is the minimum.',
#   u'Seafoam is the maximum.',
#   u'Forest Green is greater than the Steel Blue.',
#   u'Steel Blue is less than the Forest Green.',
#   u'Maroon is the high median.',
#   u'Forest Green is the low median.'],
#  163: [u'Cornflower is the minimum.',
#   u'Violet Red is the maximum.',
#   u'Periwinkle is greater than the Blue.',
#   u'Blue is less than the Periwinkle.',
#   u'Peru is the high median.',
#   u'Turquoise is the low median.'],
#  164: [u'Medium Purple is the minimum.',
#   u'Pale Green is the maximum.',
#   u'Light Green is greater than the Medium Purple.',
#   u'Medium Purple is less than the Light Green.',
#   u'Peru is the high median.',
#   u'Light Seafoam is the low median.'],
#  165: [u'Purple is the minimum.',
#   u'Dark Turquoise is the maximum.',
#   u'Dark Turquoise is greater than the Purple.',
#   u'Purple is less than the Dark Turquoise.',
#   u'Gold is the high median.',
#   u'Aqua is the low median.'],
#  166: [u'Light Seafoam is the minimum.',
#   u'Saddle Brown is the maximum.',
#   u'Gold is greater than the Firebrick.',
#   u'Firebrick is less than the Gold.',
#   u'Blue is the high median.',
#   u'Blue is the low median.'],
#  167: [u'Light Green is greater than the Medium Aqua.',
#   u'Medium Aqua is less than the Light Green.',
#   u'Light Green is the high median.',
#   u'Light Green is the low median.'],
#  168: [u'Blue is the minimum.',
#   u'Dark Gold is the maximum.',
#   u'Dark Gold is greater than the Blue.',
#   u'Blue is less than the Dark Gold.',
#   u'Dark Gold is the high median.',
#   u'Blue is the low median.'],
#  169: [u'Orange is the minimum.',
#   u'Seafoam is the maximum.',
#   u'Seafoam is greater than the Orange.',
#   u'Orange is less than the Seafoam.',
#   u'Blue Violet is the high median.',
#   u'Blue Violet is the low median.'],
#  170: [u'Royal Blue is the minimum.',
#   u'Coral is the maximum.',
#   u'Coral is greater than the Royal Blue.',
#   u'Royal Blue is less than the Coral.',
#   u'Coral is the high median.',
#   u'Royal Blue is the low median.'],
#  171: [u'Orange is the minimum.',
#   u'Green Yellow is the maximum.',
#   u'Green Yellow is greater than the Orange.',
#   u'Orange is less than the Green Yellow.',
#   u'Light Gold is the high median.',
#   u'Light Gold is the low median.'],
#  172: [u'Tomato is the minimum.',
#   u'Coral is the maximum.',
#   u'Dark Orchid is greater than the Bubblegum.',
#   u'Bubblegum is less than the Dark Orchid.',
#   u'Midnight Blue is the high median.',
#   u'Orchid is the low median.'],
#  173: [u'Orchid is greater than the Firebrick.',
#   u'Firebrick is less than the Orchid.',
#   u'Light Seafoam is the high median.',
#   u'Light Seafoam is the low median.'],
#  174: [u'Bubblegum is the minimum.',
#   u'Red is the maximum.',
#   u'Firebrick is greater than the Coral.',
#   u'Coral is less than the Firebrick.',
#   u'Firebrick is the high median.',
#   u'Dark Green is the low median.'],
#  175: [u'Forest Green is greater than the Green Yellow.',
#   u'Green Yellow is less than the Forest Green.',
#   u'Khaki is the high median.',
#   u'Violet Red is the low median.'],
#  176: [u'Violet Red is the minimum.',
#   u'Gold is the maximum.',
#   u'Orchid is greater than the Violet Red.',
#   u'Violet Red is less than the Orchid.',
#   u'Dark Turquoise is the high median.',
#   u'Medium Aqua is the low median.'],
#  177: [u'Orange is greater than the Dark Red.',
#   u'Dark Red is less than the Orange.',
#   u'Violet Red is the high median.',
#   u'Medium Purple is the low median.'],
#  178: [u'Medium Aqua is the minimum.',
#   u'Light Gold is the maximum.',
#   u'Light Gold is greater than the Medium Aqua.',
#   u'Medium Aqua is less than the Light Gold.',
#   u'Light Gold is the high median.',
#   u'Medium Aqua is the low median.'],
#  179: [u'Maroon is the minimum.',
#   u'Dark Orange is the maximum.',
#   u'Dark Red is greater than the Orange.',
#   u'Orange is less than the Dark Red.',
#   u'Orchid is the high median.',
#   u'Orchid is the low median.'],
#  180: [u'Aqua is the minimum.',
#   u'Medium Purple is the maximum.',
#   u'Medium Purple is greater than the Aqua.',
#   u'Aqua is less than the Medium Purple.',
#   u'Khaki is the high median.',
#   u'Khaki is the low median.'],
#  181: [u'Red is the minimum.',
#   u'Forest Green is the maximum.',
#   u'Forest Green is greater than the Red.',
#   u'Red is less than the Forest Green.',
#   u'Coral is the high median.',
#   u'Maroon is the low median.'],
#  182: [u'Light Green is the minimum.',
#   u'Firebrick is the maximum.',
#   u'Firebrick is greater than the Light Green.',
#   u'Light Green is less than the Firebrick.',
#   u'Gold is the high median.',
#   u'Gold is the low median.'],
#  183: [u'Medium Seafoam is the minimum.',
#   u'Gray is the maximum.',
#   u'Gray is greater than the Medium Seafoam.',
#   u'Medium Seafoam is less than the Gray.',
#   u'Gray is the high median.',
#   u'Medium Seafoam is the low median.'],
#  184: [u'Cornflower is the minimum.',
#   u'Saddle Brown is the maximum.',
#   u'Medium Blue is greater than the Khaki.',
#   u'Khaki is less than the Medium Blue.',
#   u'Khaki is the high median.',
#   u'Brown is the low median.'],
#  185: [u'Coral is the minimum.',
#   u'Medium Purple is the maximum.',
#   u'Light Slate is greater than the Khaki.',
#   u'Khaki is less than the Light Slate.',
#   u'Gold is the high median.',
#   u'Aqua is the low median.'],
#  186: [u'Orchid is the minimum.',
#   u'Dark Orchid is the maximum.',
#   u'Dark Orchid is greater than the Turquoise.',
#   u'Turquoise is less than the Dark Orchid.',
#   u'Purple is the high median.',
#   u'Purple is the low median.'],
#  187: [u'Blue is the minimum.',
#   u'Light Green is the maximum.',
#   u'Light Green is greater than the Green Yellow.',
#   u'Green Yellow is less than the Light Green.',
#   u'Gray is the high median.',
#   u'Gray is the low median.'],
#  188: [u'Turquoise is greater than the Peru.',
#   u'Peru is less than the Turquoise.',
#   u'Seafoam is the high median.',
#   u'Seafoam is the low median.'],
#  189: [u'Midnight Blue is the minimum.',
#   u'Orange Red is the maximum.',
#   u'Orange Red is greater than the Pale Green.',
#   u'Pale Green is less than the Orange Red.',
#   u'Forest Green is the high median.',
#   u'Forest Green is the low median.'],
#  190: [u'Medium Blue is greater than the Aqua.',
#   u'Aqua is less than the Medium Blue.',
#   u'Crimson is the high median.',
#   u'Orchid is the low median.'],
#  191: [u'Gray is greater than the Midnight Blue.',
#   u'Midnight Blue is less than the Gray.',
#   u'Seafoam is the high median.',
#   u'Seafoam is the low median.'],
#  192: [u'Light Slate is the minimum.',
#   u'Dark Gold is the maximum.',
#   u'Turquoise is greater than the Khaki.',
#   u'Khaki is less than the Turquoise.',
#   u'Gold is the high median.',
#   u'Midnight Blue is the low median.'],
#  193: [u'Medium Purple is the minimum.',
#   u'Light Gold is the maximum.',
#   u'Purple is greater than the Pale Green.',
#   u'Pale Green is less than the Purple.',
#   u'Light Slate is the high median.',
#   u'Light Slate is the low median.'],
#  194: [u'Dark Orange is the minimum.',
#   u'Seafoam is the maximum.',
#   u'Seafoam is greater than the Dark Blue.',
#   u'Dark Blue is less than the Seafoam.',
#   u'Dark Green is the high median.',
#   u'Dark Green is the low median.'],
#  195: [u'Orange is the minimum.',
#   u'Peru is the maximum.',
#   u'Olive is greater than the Blue.',
#   u'Blue is less than the Olive.',
#   u'Light Green is the high median.',
#   u'Light Green is the low median.'],
#  196: [u'Coral is the minimum.',
#   u'Dark Turquoise is the maximum.',
#   u'Periwinkle is greater than the Coral.',
#   u'Coral is less than the Periwinkle.',
#   u'Peru is the high median.',
#   u'Dark Blue is the low median.'],
#  197: [u'Medium Aqua is greater than the Dark Salmon.',
#   u'Dark Salmon is less than the Medium Aqua.',
#   u'Violet Red is the high median.',
#   u'Dark Salmon is the low median.'],
#  198: [u'Gray is the minimum.',
#   u'Dark Gold is the maximum.',
#   u'Dark Gold is greater than the Gray.',
#   u'Gray is less than the Dark Gold.',
#   u'Dark Gold is the high median.',
#   u'Gray is the low median.'],
#  199: [u'Steel Blue is the minimum.',
#   u'Olive is the maximum.',
#   u'Midnight Blue is greater than the Dark Green.',
#   u'Dark Green is less than the Midnight Blue.',
#   u'Dark Green is the high median.',
#   u'Dark Green is the low median.'],
#  200: [u'Medium Mint is the minimum.',
#   u'Hot Pink is the maximum.',
#   u'Hot Pink is greater than the Dark Gray.',
#   u'Dark Gray is less than the Hot Pink.',
#   u'Dark Gray is the high median.',
#   u'Dodger Blue is the low median.'],
#  201: [u'Dark Olive is the minimum.',
#   u'Sky Blue is the maximum.',
#   u'Tan is greater than the Dark Olive.',
#   u'Dark Olive is less than the Tan.',
#   u'Tan is the high median.',
#   u'Medium Mint is the low median.'],
#  202: [u'Salmon is the minimum.',
#   u'Cadet Blue is the maximum.',
#   u'Lawn Green is greater than the Salmon.',
#   u'Salmon is less than the Lawn Green.',
#   u'Olive Drab is the high median.',
#   u'Olive Drab is the low median.'],
#  203: [u'Rosy Brown is the minimum.',
#   u'Chartreuse is the maximum.',
#   u'Light Coral is greater than the Rosy Brown.',
#   u'Rosy Brown is less than the Light Coral.',
#   u'Light Coral is the high median.',
#   u'Magenta is the low median.'],
#  204: [u'Black is the minimum.',
#   u'Chocolate is the maximum.',
#   u'Chocolate is greater than the Indigo.',
#   u'Indigo is less than the Chocolate.',
#   u'Indigo is the high median.',
#   u'Indigo is the low median.'],
#  205: [u'Rebecca Purple is the minimum.',
#   u'Black is the maximum.',
#   u'Black is greater than the Deep Pink.',
#   u'Deep Pink is less than the Black.',
#   u'Deep Pink is the high median.',
#   u'Dark Seafoam is the low median.'],
#  206: [u'Light Coral is the minimum.',
#   u'Dark Cyan is the maximum.',
#   u'Rosy Brown is greater than the Yellow Green.',
#   u'Yellow Green is less than the Rosy Brown.',
#   u'Rosy Brown is the high median.',
#   u'Rosy Brown is the low median.'],
#  207: [u'Slate is the minimum.',
#   u'Rebecca Purple is the maximum.',
#   u'Tan is greater than the Slate.',
#   u'Slate is less than the Tan.',
#   u'Dark Khaki is the high median.',
#   u'Medium Mint is the low median.'],
#  208: [u'Sandy Brown is the minimum.',
#   u'Sky Blue is the maximum.',
#   u'Rebecca Purple is greater than the Sandy Brown.',
#   u'Sandy Brown is less than the Rebecca Purple.',
#   u'Rebecca Purple is the high median.',
#   u'Rebecca Purple is the low median.'],
#  209: [u'Medium Periwinkle is the minimum.',
#   u'Rebecca Purple is the maximum.',
#   u'Dark Slate is greater than the Lime Green.',
#   u'Lime Green is less than the Dark Slate.',
#   u'Lime Green is the high median.',
#   u'Dark Khaki is the low median.'],
#  210: [u'Medium Periwinkle is the minimum.',
#   u'Dim Gray is the maximum.',
#   u'Teal is greater than the Medium Periwinkle.',
#   u'Medium Periwinkle is less than the Teal.',
#   u'Teal is the high median.',
#   u'Teal is the low median.'],
#  211: [u'Deep Pink is the minimum.',
#   u'Dark Magenta is the maximum.',
#   u'Dark Magenta is greater than the Deep Pink.',
#   u'Deep Pink is less than the Dark Magenta.',
#   u'Dark Magenta is the high median.',
#   u'Deep Pink is the low median.'],
#  212: [u'Magenta is the minimum.',
#   u'Chartreuse is the maximum.',
#   u'Dark Slate is greater than the Magenta.',
#   u'Magenta is less than the Dark Slate.',
#   u'Dark Cyan is the high median.',
#   u'Dark Cyan is the low median.'],
#  213: [u'Sienna is the minimum.',
#   u'Dark Cyan is the maximum.',
#   u'Dark Cyan is greater than the Sienna.',
#   u'Sienna is less than the Dark Cyan.',
#   u'Dark Cyan is the high median.',
#   u'Sienna is the low median.'],
#  214: [u'Black is the minimum.',
#   u'Sienna is the maximum.',
#   u'Sienna is greater than the Web Gray.',
#   u'Web Gray is less than the Sienna.',
#   u'Web Maroon is the high median.',
#   u'Yellow is the low median.'],
#  215: [u'Dark Slate is the minimum.',
#   u'Medium Turquoise is the maximum.',
#   u'Yellow Green is greater than the Chocolate.',
#   u'Chocolate is less than the Yellow Green.',
#   u'Yellow Green is the high median.',
#   u'Web Green is the low median.'],
#  216: [u'Dark Slate is the minimum.',
#   u'Light Salmon is the maximum.',
#   u'Light Salmon is greater than the Rebecca Purple.',
#   u'Rebecca Purple is less than the Light Salmon.',
#   u'Rebecca Purple is the high median.',
#   u'Rebecca Purple is the low median.'],
#  217: [u'Dark Cyan is the minimum.',
#   u'Medium Periwinkle is the maximum.',
#   u'Chocolate is greater than the Dark Cyan.',
#   u'Dark Cyan is less than the Chocolate.',
#   u'Dodger Blue is the high median.',
#   u'Chocolate is the low median.'],
#  218: [u'Black is the minimum.',
#   u'Hot Pink is the maximum.',
#   u'Chartreuse is greater than the Black.',
#   u'Black is less than the Chartreuse.',
#   u'Slate is the high median.',
#   u'Slate is the low median.'],
#  219: [u'Web Green is the minimum.',
#   u'Medium Turquoise is the maximum.',
#   u'Rebecca Purple is greater than the Deep Pink.',
#   u'Deep Pink is less than the Rebecca Purple.',
#   u'Dark Olive is the high median.',
#   u'Dark Khaki is the low median.'],
#  220: [u'Web Maroon is the minimum.',
# ...
#   u'Dodger Blue has the highest value.',
#   u'Lime Green is less than Tan.',
#   u'Tan is greater than Lime Green.',
#   u'Dodger Blue intersects Web Gray.'],
#  956: [u'Sky Blue has the minimum area under curve.',
#   u'Black has the maximum area under curve.',
#   u'Black is the smoothest.',
#   u'Medium Turquoise is the roughest.',
#   u'Navy Blue has the lowest value.',
#   u'Black has the highest value.',
#   u'Rebecca Purple is less than Black.',
#   u'Black is greater than Dark Khaki.',
#   u'Rebecca Purple intersects Medium Turquoise.'],
#  957: [u'Sky Blue has the minimum area under curve.',
#   u'Hot Pink has the maximum area under curve.',
#   u'Hot Pink is the smoothest.',
#   u'Sky Blue is the roughest.',
#   u'Sky Blue has the lowest value.',
#   u'Lime Green has the highest value.',
#   u'Sky Blue is less than Hot Pink.',
#   u'Burlywood is greater than Deep Pink.',
#   u'Burlywood intersects Hot Pink.'],
#  958: [u'Chocolate has the minimum area under curve.',
#   u'Sandy Brown has the maximum area under curve.',
#   u'Sandy Brown is the smoothest.',
#   u'Chocolate is the roughest.',
#   u'Dark Seafoam has the lowest value.',
#   u'Sandy Brown has the highest value.',
#   u'Dim Gray intersects Chocolate.'],
#  959: [u'Slate has the minimum area under curve.',
#   u'Chocolate has the maximum area under curve.',
#   u'Chocolate is the smoothest.',
#   u'Cadet Blue is the roughest.',
#   u'Web Gray has the lowest value.',
#   u'Cadet Blue has the highest value.',
#   u'Slate is less than Medium Periwinkle.',
#   u'Chocolate is greater than Web Gray.',
#   u'Medium Periwinkle intersects Dark Magenta.'],
#  960: [u'Web Maroon has the minimum area under curve.',
#   u'Tan has the maximum area under curve.',
#   u'Web Maroon is the smoothest.',
#   u'Tan is the roughest.',
#   u'Web Maroon has the lowest value.',
#   u'Tan has the highest value.',
#   u'Web Maroon is less than Tan.',
#   u'Tan is greater than Web Maroon.'],
#  961: [u'Rebecca Purple has the minimum area under curve.',
#   u'Medium Mint has the maximum area under curve.',
#   u'Burlywood is the smoothest.',
#   u'Medium Mint is the roughest.',
#   u'Rebecca Purple has the lowest value.',
#   u'Yellow has the highest value.',
#   u'Rebecca Purple is less than Medium Mint.',
#   u'Burlywood is greater than Rebecca Purple.',
#   u'Medium Mint intersects Lawn Green.'],
#  962: [u'Black has the minimum area under curve.',
#   u'Lime Green has the maximum area under curve.',
#   u'Dark Gray is the smoothest.',
#   u'Sandy Brown is the roughest.',
#   u'Dark Gray has the lowest value.',
#   u'Lime Green has the highest value.',
#   u'Dark Gray is less than Sandy Brown.',
#   u'Sandy Brown is greater than Web Maroon.',
#   u'Web Maroon intersects Black.'],
#  963: [u'Indian Red has the minimum area under curve.',
#   u'Salmon has the maximum area under curve.',
#   u'Dodger Blue is the smoothest.',
#   u'Indian Red is the roughest.',
#   u'Yellow Green has the lowest value.',
#   u'Salmon has the highest value.',
#   u'Deep Pink is less than Salmon.',
#   u'Salmon is greater than Dodger Blue.',
#   u'Yellow Green intersects Indian Red.'],
#  964: [u'Rosy Brown has the minimum area under curve.',
#   u'Black has the maximum area under curve.',
#   u'Olive Drab is the smoothest.',
#   u'Violet is the roughest.',
#   u'Rosy Brown has the lowest value.',
#   u'Olive Drab has the highest value.',
#   u'Violet is less than Dodger Blue.',
#   u'Black is greater than Violet.',
#   u'Olive Drab intersects Dodger Blue.'],
#  965: [u'Dark Olive has the minimum area under curve.',
#   u'Indigo has the maximum area under curve.',
#   u'Dark Olive is the smoothest.',
#   u'Indigo is the roughest.',
#   u'Indigo has the lowest value.',
#   u'Indigo has the highest value.',
#   u'Indigo intersects Dark Olive.'],
#  966: [u'Dark Periwinkle has the minimum area under curve.',
#   u'Light Coral has the maximum area under curve.',
#   u'Salmon is the smoothest.',
#   u'Chartreuse is the roughest.',
#   u'Salmon has the lowest value.',
#   u'Light Coral has the highest value.',
#   u'Dark Periwinkle is less than Light Salmon.',
#   u'Light Salmon is greater than Salmon.',
#   u'Dark Periwinkle intersects Salmon.'],
#  967: [u'Deep Sky Blue has the minimum area under curve.',
#   u'Hot Pink has the maximum area under curve.',
#   u'Deep Sky Blue is the smoothest.',
#   u'Burlywood is the roughest.',
#   u'Deep Sky Blue has the lowest value.',
#   u'Hot Pink has the highest value.',
#   u'Deep Sky Blue is less than Burlywood.',
#   u'Burlywood is greater than Deep Sky Blue.',
#   u'Hot Pink intersects Burlywood.'],
#  968: [u'Sandy Brown has the minimum area under curve.',
#   u'Lawn Green has the maximum area under curve.',
#   u'Lawn Green is the smoothest.',
#   u'Web Gray is the roughest.',
#   u'Web Gray has the lowest value.',
#   u'Lawn Green has the highest value.',
#   u'Sandy Brown is less than Lawn Green.',
#   u'Lawn Green is greater than Sandy Brown.',
#   u'Sandy Brown intersects Web Gray.'],
#  969: [u'Violet has the minimum area under curve.',
#   u'Dark Gray has the maximum area under curve.',
#   u'Cadet Blue is the smoothest.',
#   u'Violet is the roughest.',
#   u'Cadet Blue has the lowest value.',
#   u'Dark Gray has the highest value.',
#   u'Burlywood is less than Dark Gray.',
#   u'Dark Gray is greater than Dark Seafoam.',
#   u'Violet intersects Burlywood.'],
#  970: [u'Sky Blue has the minimum area under curve.',
#   u'Sandy Brown has the maximum area under curve.',
#   u'Sky Blue is the smoothest.',
#   u'Dark Violet is the roughest.',
#   u'Web Gray has the lowest value.',
#   u'Dark Violet has the highest value.',
#   u'Mint is less than Sandy Brown.',
#   u'Mint is greater than Sky Blue.',
#   u'Dark Violet intersects Chartreuse.'],
#  971: [u'Indian Red has the minimum area under curve.',
#   u'Sienna has the maximum area under curve.',
#   u'Light Sky Blue is the smoothest.',
#   u'Dark Gray is the roughest.',
#   u'Dark Khaki has the lowest value.',
#   u'Light Sky Blue has the highest value.',
#   u'Indian Red is less than Dark Gray.',
#   u'Sienna is greater than Indian Red.',
#   u'Dark Khaki intersects Light Sky Blue.'],
#  972: [u'Medium Periwinkle has the minimum area under curve.',
#   u'Dodger Blue has the maximum area under curve.',
#   u'Dodger Blue is the smoothest.',
#   u'Deep Pink is the roughest.',
#   u'Deep Pink has the lowest value.',
#   u'Teal has the highest value.',
#   u'Tan is less than Dodger Blue.',
#   u'Light Salmon is greater than Medium Periwinkle.',
#   u'Deep Pink intersects Tan.'],
#  973: [u'Dim Gray has the minimum area under curve.',
#   u'Rosy Brown has the maximum area under curve.',
#   u'Dim Gray is the smoothest.',
#   u'Rosy Brown is the roughest.',
#   u'Dim Gray has the lowest value.',
#   u'Rosy Brown has the highest value.',
#   u'Green is less than Rosy Brown.',
#   u'Rosy Brown is greater than Green.'],
#  974: [u'Dim Gray has the minimum area under curve.',
#   u'Indian Red has the maximum area under curve.',
#   u'Dim Gray is the smoothest.',
#   u'Dark Slate is the roughest.',
#   u'Dark Olive has the lowest value.',
#   u'Indian Red has the highest value.',
#   u'Chartreuse is less than Dark Slate.',
#   u'Cadet Blue is greater than Chartreuse.',
#   u'Dark Olive intersects Indian Red.'],
#  975: [u'Cadet Blue has the minimum area under curve.',
#   u'Yellow has the maximum area under curve.',
#   u'Violet is the smoothest.',
#   u'Sandy Brown is the roughest.',
#   u'Dark Olive has the lowest value.',
#   u'Yellow has the highest value.',
#   u'Sandy Brown is less than Yellow.',
#   u'Yellow is greater than Cadet Blue.',
#   u'Cadet Blue intersects Violet.'],
#  976: [u'Mint has the minimum area under curve.',
#   u'Dark Khaki has the maximum area under curve.',
#   u'Dark Khaki is the smoothest.',
#   u'Mint is the roughest.',
#   u'Mint has the lowest value.',
#   u'Dark Khaki has the highest value.',
#   u'Mint is less than Dark Khaki.',
#   u'Dark Khaki is greater than Mint.'],
#  977: [u'Salmon has the minimum area under curve.',
#   u'Burlywood has the maximum area under curve.',
#   u'Burlywood is the smoothest.',
#   u'Salmon is the roughest.',
#   u'Salmon has the lowest value.',
#   u'Burlywood has the highest value.',
#   u'Salmon is less than Burlywood.',
#   u'Burlywood is greater than Salmon.'],
#  978: [u'Cadet Blue has the minimum area under curve.',
#   u'Olive Drab has the maximum area under curve.',
#   u'Cadet Blue is the smoothest.',
#   u'Lime Green is the roughest.',
#   u'Cadet Blue has the lowest value.',
#   u'Olive Drab has the highest value.',
#   u'Lime Green intersects Cadet Blue.'],
#  979: [u'Dark Olive has the minimum area under curve.',
#   u'Indian Red has the maximum area under curve.',
#   u'Dark Olive is the smoothest.',
#   u'Indian Red is the roughest.',
#   u'Dark Olive has the lowest value.',
#   u'Indian Red has the highest value.',
#   u'Dark Olive intersects Indian Red.'],
#  980: [u'Olive Drab has the minimum area under curve.',
#   u'Dark Olive has the maximum area under curve.',
#   u'Dark Olive is the smoothest.',
#   u'Olive Drab is the roughest.',
#   u'Dark Olive has the lowest value.',
#   u'Dark Olive has the highest value.',
#   u'Olive Drab intersects Dark Olive.'],
#  981: [u'Hot Pink has the minimum area under curve.',
#   u'Chartreuse has the maximum area under curve.',
#   u'Chartreuse is the smoothest.',
#   u'Hot Pink is the roughest.',
#   u'Hot Pink has the lowest value.',
#   u'Chartreuse has the highest value.',
#   u'Hot Pink is less than Light Coral.',
#   u'Light Coral is greater than Hot Pink.',
#   u'Light Coral intersects Chartreuse.'],
#  982: [u'Green has the minimum area under curve.',
#   u'Rebecca Purple has the maximum area under curve.',
#   u'Green is the smoothest.',
#   u'Light Salmon is the roughest.',
#   u'Green has the lowest value.',
#   u'Rebecca Purple has the highest value.',
#   u'Yellow Green is less than Light Salmon.',
#   u'Rebecca Purple is greater than Deep Sky Blue.',
#   u'Deep Sky Blue intersects Web Green.'],
#  983: [u'Dark Cyan has the minimum area under curve.',
#   u'Chartreuse has the maximum area under curve.',
#   u'Chartreuse is the smoothest.',
#   u'Violet is the roughest.',
#   u'Dark Cyan has the lowest value.',
#   u'Chartreuse has the highest value.',
#   u'Dark Cyan is less than Dark Violet.',
#   u'Chartreuse is greater than Dark Cyan.',
#   u'Chartreuse intersects Dark Violet.'],
#  984: [u'Chocolate has the minimum area under curve.',
#   u'Dark Slate has the maximum area under curve.',
#   u'Dark Slate is the smoothest.',
#   u'Light Coral is the roughest.',
#   u'Dark Slate has the lowest value.',
#   u'Dark Slate has the highest value.',
#   u'Chocolate is less than Light Coral.',
#   u'Light Coral is greater than Chocolate.',
#   u'Light Coral intersects Dark Slate.'],
#  985: [u'Violet has the minimum area under curve.',
#   u'Olive Drab has the maximum area under curve.',
#   u'Rebecca Purple is the smoothest.',
#   u'Deep Sky Blue is the roughest.',
#   u'Light Salmon has the lowest value.',
#   u'Rebecca Purple has the highest value.',
#   u'Light Salmon is less than Olive Drab.',
#   u'Rebecca Purple is greater than Chocolate.',
#   u'Olive Drab intersects Rebecca Purple.'],
#  986: [u'Medium Mint has the minimum area under curve.',
#   u'Dark Cyan has the maximum area under curve.',
#   u'Teal is the smoothest.',
#   u'Dark Magenta is the roughest.',
#   u'Medium Mint has the lowest value.',
#   u'Dark Cyan has the highest value.',
#   u'Dark Magenta is less than Dark Cyan.',
#   u'Dark Cyan is greater than Dark Magenta.',
#   u'Medium Mint intersects Dark Magenta.'],
#  987: [u'Hot Pink has the minimum area under curve.',
#   u'Sienna has the maximum area under curve.',
#   u'Mint is the smoothest.',
#   u'Dodger Blue is the roughest.',
#   u'Hot Pink has the lowest value.',
#   u'Sienna has the highest value.',
#   u'Magenta is less than Sienna.',
#   u'Salmon is greater than Mint.',
#   u'Sienna intersects Dodger Blue.'],
#  988: [u'Olive Drab has the minimum area under curve.',
#   u'Dark Slate has the maximum area under curve.',
#   u'Dark Slate is the smoothest.',
#   u'Dark Violet is the roughest.',
#   u'Dark Violet has the lowest value.',
#   u'Hot Pink has the highest value.',
#   u'Dark Violet is less than Dark Slate.',
#   u'Dark Slate is greater than Dark Violet.',
#   u'Hot Pink intersects Dark Slate.'],
#  989: [u'Indigo has the minimum area under curve.',
#   u'Dark Olive has the maximum area under curve.',
#   u'Indigo is the smoothest.',
#   u'Dark Khaki is the roughest.',
#   u'Dark Cyan has the lowest value.',
#   u'Dark Olive has the highest value.',
#   u'Dark Cyan is less than Dark Olive.',
#   u'Dark Olive is greater than Light Sky Blue.',
#   u'Dark Khaki intersects Dark Cyan.'],
#  990: [u'Dodger Blue has the minimum area under curve.',
#   u'Hot Pink has the maximum area under curve.',
#   u'Dark Magenta is the smoothest.',
#   u'Hot Pink is the roughest.',
#   u'Web Gray has the lowest value.',
#   u'Web Gray has the highest value.',
#   u'Dodger Blue is less than Hot Pink.',
#   u'Hot Pink is greater than Dark Magenta.',
#   u'Hot Pink intersects Web Gray.'],
#  991: [u'Dark Seafoam has the minimum area under curve.',
#   u'Dark Cyan has the maximum area under curve.',
#   u'Dark Seafoam is the smoothest.',
#   u'Dark Slate is the roughest.',
#   u'Dark Cyan has the lowest value.',
#   u'Dark Cyan has the highest value.',
#   u'Dark Seafoam intersects Dark Slate.'],
#  992: [u'Web Gray has the minimum area under curve.',
#   u'Medium Mint has the maximum area under curve.',
#   u'Yellow Green is the smoothest.',
#   u'Medium Periwinkle is the roughest.',
#   u'Medium Periwinkle has the lowest value.',
#   u'Yellow Green has the highest value.',
#   u'Medium Periwinkle is less than Medium Mint.',
#   u'Medium Mint is greater than Medium Periwinkle.',
#   u'Medium Periwinkle intersects Web Gray.'],
#  993: [u'Dark Khaki has the minimum area under curve.',
#   u'Dark Seafoam has the maximum area under curve.',
#   u'Dark Seafoam is the smoothest.',
#   u'Dark Khaki is the roughest.',
#   u'Dark Khaki has the lowest value.',
#   u'Dark Seafoam has the highest value.',
#   u'Dark Seafoam intersects Dark Khaki.'],
#  994: [u'Rebecca Purple has the minimum area under curve.',
#   u'Teal has the maximum area under curve.',
#   u'Sienna is the smoothest.',
#   u'Rebecca Purple is the roughest.',
#   u'Sienna has the lowest value.',
#   u'Teal has the highest value.',
#   u'Rebecca Purple is less than Teal.',
#   u'Teal is greater than Rebecca Purple.',
#   u'Teal intersects Sienna.'],
#  995: [u'Lime Green has the minimum area under curve.',
#   u'Mint has the maximum area under curve.',
#   u'Mint is the smoothest.',
#   u'Dark Cyan is the roughest.',
#   u'Dark Cyan has the lowest value.',
#   u'Mint has the highest value.',
#   u'Hot Pink is less than Green.',
#   u'Green is greater than Lime Green.',
#   u'Lime Green intersects Mint.'],
#  996: [u'Deep Sky Blue has the minimum area under curve.',
#   u'Violet has the maximum area under curve.',
#   u'Violet is the smoothest.',
#   u'Dark Cyan is the roughest.',
#   u'Dark Cyan has the lowest value.',
#   u'Violet has the highest value.',
#   u'Dark Cyan is less than Violet.',
#   u'Violet is greater than Dark Cyan.',
#   u'Deep Sky Blue intersects Dark Cyan.'],
#  997: [u'Medium Turquoise has the minimum area under curve.',
#   u'Dark Gray has the maximum area under curve.',
#   u'Dark Gray is the smoothest.',
#   u'Dodger Blue is the roughest.',
#   u'Magenta has the lowest value.',
#   u'Dark Gray has the highest value.',
#   u'Medium Turquoise is less than Dark Gray.',
#   u'Dark Gray is greater than Medium Turquoise.',
#   u'Magenta intersects Medium Turquoise.'],
#  998: [u'Black has the minimum area under curve.',
#   u'Green has the maximum area under curve.',
#   u'Dark Periwinkle is the smoothest.',
#   u'Dodger Blue is the roughest.',
#   u'Dodger Blue has the lowest value.',
#   u'Dark Periwinkle has the highest value.',
#   u'Rebecca Purple is less than Dark Periwinkle.',
#   u'Rebecca Purple is greater than Black.',
#   u'Green intersects Dark Periwinkle.'],
#  999: [u'Web Maroon has the minimum area under curve.',
#   u'Lawn Green has the maximum area under curve.',
#   u'Lawn Green is the smoothest.',
#   u'Dark Seafoam is the roughest.',
#   u'Dark Seafoam has the lowest value.',
#   u'Lawn Green has the highest value.',
#   u'Web Maroon is less than Sandy Brown.',
#   u'Sandy Brown is greater than Web Maroon.',
#   u'Web Maroon intersects Dark Seafoam.']}

# %%
b = a.split()

# %%
b[0], b[1] = b[1], b[0]

# %%
b
# Out:
# [u'Dark', u'Is', u'Turquoise', u'the', u'minimum?']
